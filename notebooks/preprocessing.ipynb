# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')
# %matplotlib inline

import warnings 
warnings.filterwarnings("ignore")

df = pd.read_csv('../data/telco.csv')
df.head()
# Out:
#   Customer ID  Gender  Age Under 30 Senior Citizen Married Dependents  \
# 0  8779-QRDMV    Male   78       No            Yes      No         No
# 1  7495-OOKFY  Female   74       No            Yes     Yes        Yes
# 2  1658-BYGOY    Male   71       No            Yes      No        Yes
# 3  4598-XLKNJ  Female   78       No            Yes     Yes        Yes
# 4  4846-WHAFZ  Female   80       No            Yes     Yes        Yes
#
#    Number of Dependents        Country       State  ...  \
# 0                     0  United States  California  ...
# 1                     1  United States  California  ...
# 2                     3  United States  California  ...
# 3                     1  United States  California  ...
# 4                     1  United States  California  ...
#
#   Total Extra Data Charges  Total Long Distance Charges  Total Revenue  \
# 0                       20                         0.00          59.65
# 1                        0                       390.80        1024.10
# 2                        0                       203.94        1910.88
# 3                        0                       494.00        2995.07
# 4                        0                       234.21        3102.36
#
#    Satisfaction Score  Customer Status Churn Label Churn Score  CLTV  \
# 0                   3          Churned         Yes          91  5433
# 1                   3          Churned         Yes          69  5302
# 2                   2          Churned         Yes          81  3179
# 3                   2          Churned         Yes          88  5337
# 4                   2          Churned         Yes          67  2793
#
#     Churn Category                  Churn Reason
# 0       Competitor  Competitor offered more data
# 1       Competitor  Competitor made better offer
# 2       Competitor  Competitor made better offer
# 3  Dissatisfaction     Limited range of services
# 4            Price            Extra data charges
#
# [5 rows x 50 columns]

# %%
# Create a copy of the original dataframe
df_processed = df.copy()

# %%
columns_to_drop = [
    'Customer ID',
    'Country',
    'State',
    'Quarter',
    'Customer Status',
    'Churn Score',
    'Churn Category',
    'Churn Reason',
    'CLTV',
    'City',
    'Zip Code',
    'Total Revenue'
]

df_processed.drop(columns=columns_to_drop, inplace=True)

print(df_processed.shape)
# Out:
# (7043, 38)

# %%
df_processed['Offer'] = df_processed['Offer'].fillna('No Offer')

df_processed['Internet Type'] = (
    df_processed['Internet Type']
    .fillna('No Internet Service')
)

# %%
df_processed[['Offer', 'Internet Type']].isnull().sum()
# Out:
# Offer            0
# Internet Type    0
# dtype: int64

# %%
df_processed['Churn Label'] = (
    df_processed['Churn Label']
    .map({'Yes': 1, 'No': 0})
)

# %%
X = df_processed.drop('Churn Label', axis=1)
y = df_processed['Churn Label']

# %%
categorical_cols = X.select_dtypes(include='object').columns

X = pd.get_dummies(
    X,
    columns=categorical_cols,
    drop_first=True,
    dtype=int
)

print(X.shape)
# Out:
# (7043, 45)

# %%
print(X.info())

print()

print(y.value_counts())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 45 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                7043 non-null   int64
#  1   Number of Dependents               7043 non-null   int64
#  2   Latitude                           7043 non-null   float64
#  3   Longitude                          7043 non-null   float64
#  4   Population                         7043 non-null   int64
#  5   Number of Referrals                7043 non-null   int64
#  6   Tenure in Months                   7043 non-null   int64
#  7   Avg Monthly Long Distance Charges  7043 non-null   float64
#  8   Avg Monthly GB Download            7043 non-null   int64
#  9   Monthly Charge                     7043 non-null   float64
#  10  Total Charges                      7043 non-null   float64
#  11  Total Refunds                      7043 non-null   float64
#  12  Total Extra Data Charges           7043 non-null   int64
#  13  Total Long Distance Charges        7043 non-null   float64
#  14  Satisfaction Score                 7043 non-null   int64
#  15  Gender_Male                        7043 non-null   int64
#  16  Under 30_Yes                       7043 non-null   int64
#  17  Senior Citizen_Yes                 7043 non-null   int64
#  18  Married_Yes                        7043 non-null   int64
#  19  Dependents_Yes                     7043 non-null   int64
#  20  Referred a Friend_Yes              7043 non-null   int64
#  21  Offer_Offer A                      7043 non-null   int64
#  22  Offer_Offer B                      7043 non-null   int64
#  23  Offer_Offer C                      7043 non-null   int64
#  24  Offer_Offer D                      7043 non-null   int64
#  25  Offer_Offer E                      7043 non-null   int64
#  26  Phone Service_Yes                  7043 non-null   int64
#  27  Multiple Lines_Yes                 7043 non-null   int64
#  28  Internet Service_Yes               7043 non-null   int64
#  29  Internet Type_DSL                  7043 non-null   int64
#  30  Internet Type_Fiber Optic          7043 non-null   int64
#  31  Internet Type_No Internet Service  7043 non-null   int64
#  32  Online Security_Yes                7043 non-null   int64
#  33  Online Backup_Yes                  7043 non-null   int64
#  34  Device Protection Plan_Yes         7043 non-null   int64
#  35  Premium Tech Support_Yes           7043 non-null   int64
#  36  Streaming TV_Yes                   7043 non-null   int64
#  37  Streaming Movies_Yes               7043 non-null   int64
#  38  Streaming Music_Yes                7043 non-null   int64
#  39  Unlimited Data_Yes                 7043 non-null   int64
#  40  Contract_One Year                  7043 non-null   int64
#  41  Contract_Two Year                  7043 non-null   int64
#  42  Paperless Billing_Yes              7043 non-null   int64
#  43  Payment Method_Credit Card         7043 non-null   int64
#  44  Payment Method_Mailed Check        7043 non-null   int64
# dtypes: float64(7), int64(38)
# memory usage: 2.4 MB
# None
#
# Churn Label
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %%
processed_data = X.copy()
processed_data["Churn Label"] = y

processed_data.to_csv(
    "Preprocessed.csv",
    index=False
)
